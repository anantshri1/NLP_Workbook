# %% [markdown]
# Imports and Initialization

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import (roc_auc_score, classification_report,
                             confusion_matrix, ConfusionMatrixDisplay)
from sklearn.ensemble import RandomForestClassifier
from sklearn.decomposition import PCA, KernelPCA
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.svm import SVC
from sklearn.naive_bayes import MultinomialNB
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split

import random

# %%
import kagglehub

# %%
np.random.seed(0)
random.seed(0)

# %%
path = kagglehub.dataset_download("nikhiljohnk/tweets-with-sarcasm-and-irony")

# %%
train = pd.read_csv(path+'/train.csv')
train.head(5)
# Out:
#                                               tweets       class
# 0  Be aware  dirty step to get money  #staylight ...  figurative
# 1  #sarcasm for #people who don't understand #diy...  figurative
# 2  @IminworkJeremy @medsingle #DailyMail readers ...  figurative
# 3  @wilw Why do I get the feeling you like games?...  figurative
# 4  -@TeacherArthurG @rweingarten You probably jus...  figurative

# %%
labels_class = (train['class'].value_counts()).index
colors = sns.color_palette('pastel')

fig, ax = plt.subplots()

wedges, texts, autotexts = ax.pie(
    train['class'].value_counts(),
    labels=labels_class,
    colors=colors,
    startangle=90,
    autopct='%1.2f%%',
    wedgeprops=dict(width=0.5)
)

ax.legend(wedges, labels_class, title="Class", bbox_to_anchor=(1, 0, 0.5, 1))
plt.title('Tweets by Class')
plt.show()

# %%
test = pd.read_csv(path+'/test.csv')
test.head(5)
# Out:
#                                               tweets       class
# 0  no one ever predicted this was going to happen...  figurative
# 1  @Stooshie its as closely related as Andrews or...  figurative
# 2  I find it ironic when Vegans say they love foo...  figurative
# 3  Quick rt that throwing money vine I've not see...  figurative
# 4  yep, keep adding me to your #devops lists.... ...  figurative

# %% [markdown]
# NLP Toolkit

# %%
import nltk
nltk.download('stopwords')
nltk.download('wordnet')

from nltk.corpus import stopwords          # module for stop words that come with NLTK
from nltk.stem import PorterStemmer,WordNetLemmatizer         # module for stemming
from nltk.tokenize import TweetTokenizer,sent_tokenize,word_tokenize   # module for tokenizing strings

import re                                  # library for regular expression operations
import string                              # for string operations
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /usr/local/lib/python3.13/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /usr/local/lib/python3.13/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
# tweet preprocessing #
def preprocess_tweets(tweet):
    # cleans the tweet after removing extra stop words, punctuation etc. After this, the tweet needs to be tokenized, into words & then words converted into their respective lemma
    tweets_clean = []
    
    # Instantiate stemming class
    Lemma = WordNetLemmatizer()
    
    # Create an empty list to store the stems
    tweets_lemma = []

    stopwords_english = stopwords.words('english') 
    tokenizer = TweetTokenizer(preserve_case=False, strip_handles=True,reduce_len=True)
    
    tweet2 = re.sub(r'^RT[\s]+', '', tweet)
    # remove hyperlinks
    tweet2 = re.sub(r'https?:\/\/.*[\r\n]*', '', tweet2)
    
    tweet2 = re.sub(r'#', '', tweet2)   # remove hashtags
    
    tweet2 = re.sub(r"@\w+","", tweet2)        # remove mentions
    

    tweet_tokens = tokenizer.tokenize(tweet2)
    
    for word_token in tweet_tokens:
        if(word_token not in stopwords_english and word_token not in string.punctuation):
            stem_word = Lemma.lemmatize(word_token)
            tweets_clean.append(stem_word)
    
    return tweets_clean

# %%
train.tweets.apply(preprocess_tweets)
# Out:
# 0        [aware, dirty, step, get, money, staylight, st...
# 1            [sarcasm, people, understand, diy, artattack]
# 2        [dailymail, reader, sensible, always, shocker,...
# 3                      [get, feeling, like, game, sarcasm]
# 4                      [probably, missed, text, sarcastic]
#                                ...
# 81403                           [photo, image, via, heart]
# 81404    [never, knew, .., better, put, universe, lol, ...
# 81405    [hey, wanted, say, thanks, puberty, letting, a...
# 81406    [sure, coverage, like, fox, news, special, “, ...
# 81407               [u13, believe, see, ..., :-P, sarcasm]
# Name: tweets, Length: 81408, dtype: object

# %%
le = LabelEncoder()
train['class'] = le.fit_transform(train['class'])

# %%
X_train, X_test, y_train, y_test = train_test_split(train['tweets'], train['class'],
                                               test_size = 0.20, stratify = train['class'],
                                               random_state = 0)

X_train = X_train.reset_index(drop=True)
X_test = X_test.reset_index(drop=True)
y_train = y_train.reset_index(drop=True)
y_test = y_test.reset_index(drop=True)

# %%
def build_freq(tweets,label):
    ys = label
    yslist = np.squeeze(ys).tolist()

    freq = {}

    for tweet,y in zip(tweets,ys):
        for word in preprocess_tweets(tweet):
            pair = (word,y)
            if pair in freq:
                freq[pair] += 1
            else:
                freq[pair] = 1
    return freq

freqs = build_freq(X_train, y_train)

# %%
def extract_feature_map_multiclass(tweet, freq, classes=[0.0, 1.0, 2.0, 3.0]):
    clean_word = preprocess_tweets(tweet)
    x = np.zeros((1, len(classes) + 1))
    x[0, 0] = 1  # bias term
    for word in clean_word:
        for i, c in enumerate(classes):
            x[0, i+1] += freq.get((word, c), 0)
    return x

# %%
classes = [0, 1, 2, 3]  

X = np.zeros((len(X_train), len(classes) + 1))
for i in range(len(X_train)):
    X[i] = extract_feature_map_multiclass(X_train[i], freqs, classes)
y = y_train

X_test_matrix = np.zeros((len(X_test), len(classes) + 1))
for i in range(len(X_test)):
    X_test_matrix[i] = extract_feature_map_multiclass(X_test[i], freqs, classes)

# %%
np.unique(y_train)
# Out:
# array([0, 1, 2, 3])

# %% [markdown]
# Baseline: Naive Bayes

# %%
MB = MultinomialNB(alpha=1)
MB.fit(X,y)
# Out:
# MultinomialNB(alpha=1)

# %%
Pred_y_nb = MB.predict(X_test_matrix)
y_pred_proba_nb = MB.predict_proba(X_test_matrix)

# %%
print(classification_report(y_test, Pred_y_nb,
      target_names=le.classes_.astype(str)))
# Out:
#               precision    recall  f1-score   support
#
#   figurative       0.26      0.03      0.05      4248
#        irony       0.66      0.95      0.78      4179
#      regular       0.93      0.97      0.95      3719
#      sarcasm       0.66      0.94      0.78      4136
#
#     accuracy                           0.71     16282
#    macro avg       0.63      0.72      0.64     16282
# weighted avg       0.62      0.71      0.63     16282

# %%
cm_nb = confusion_matrix(y_test, Pred_y_nb)
ConfusionMatrixDisplay(cm_nb, display_labels=le.classes_.astype(str)).plot(cmap='Blues')
plt.show()

# %% [markdown]
# Model 2: Random Forest

# %%
model_rf = RandomForestClassifier(class_weight='balanced', n_estimators = 3000)
model_rf.fit(X,y)
# Out:
# RandomForestClassifier(class_weight='balanced', n_estimators=3000)

# %%
Pred_y_rf = model_rf.predict(X_test_matrix)
y_pred_proba_rf = model_rf.predict_proba(X_test_matrix)

# %%
print(classification_report(y_test, Pred_y_rf,
      target_names=le.classes_.astype(str)))
# Out:
#               precision    recall  f1-score   support
#
#   figurative       0.07      0.05      0.06      4248
#        irony       0.56      0.64      0.60      4179
#      regular       0.96      0.99      0.97      3719
#      sarcasm       0.60      0.71      0.65      4136
#
#     accuracy                           0.58     16282
#    macro avg       0.55      0.60      0.57     16282
# weighted avg       0.54      0.58      0.56     16282

# %%
cm_rf = confusion_matrix(y_test, Pred_y_rf)
ConfusionMatrixDisplay(cm_rf, display_labels=le.classes_.astype(str)).plot(cmap='Blues')
plt.show()

# %% [markdown]
# Model 3: XGBoost

# %%
from xgboost import XGBClassifier

# %%
model_x = XGBClassifier(
    n_estimators=400,
    max_depth=6,
    learning_rate=0.01,
    subsample=0.8,
    colsample_bytree=0.8,
    random_state=0,
    n_jobs=-1,
    eval_metric='mlogloss'
)
model_x.fit(X,y)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.8, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='mlogloss',
#               feature_types=None, feature_weights=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.01, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=6, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=400, n_jobs=-1,
#               num_parallel_tree=None, ...)

# %%
Pred_y_x = model_x.predict(X_test_matrix)
y_pred_proba_x = model_x.predict_proba(X_test_matrix)

# %%
print(classification_report(y_test, Pred_y_x,
      target_names=le.classes_.astype(str)))
# Out:
#               precision    recall  f1-score   support
#
#   figurative       0.21      0.00      0.00      4248
#        irony       0.66      0.97      0.78      4179
#      regular       0.93      1.00      0.96      3719
#      sarcasm       0.66      0.98      0.79      4136
#
#     accuracy                           0.72     16282
#    macro avg       0.61      0.74      0.63     16282
# weighted avg       0.60      0.72      0.62     16282

# %%
cm_x = confusion_matrix(y_test, Pred_y_x)
ConfusionMatrixDisplay(cm_x, display_labels=le.classes_.astype(str)).plot(cmap='Blues')
plt.show()

# %% [markdown]
# Model 4: Neural Nets

# %%
import tensorflow as tf
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import EarlyStopping
tf.random.set_seed(0)

# %%
def build_classifier():
    model = Sequential([
        Dense(128, activation='relu', input_shape=[X.shape[1]]),
        BatchNormalization(),
        Dropout(0.2),
        
        Dense(64, activation='relu'),
        BatchNormalization(),
        Dropout(0.2),

        Dense(32, activation='relu'),
        BatchNormalization(),
        Dropout(0.2),

        Dense(4, activation='softmax')
    ])
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
        loss='sparse_categorical_crossentropy',
        metrics=['accuracy']
    )
    return model

# %%
model_nn = build_classifier()
print(model_nn.summary())
# Out:
# /usr/local/lib/python3.13/site-packages/keras/src/layers/core/dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_6 (Dense)                 │ (None, 128)            │           768 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 4)              │           132 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 12,132 (47.39 KB)
#  Trainable params: 11,684 (45.64 KB)
#  Non-trainable params: 448 (1.75 KB)
# None

# %%
early_stop = EarlyStopping(
    monitor='val_loss',
    patience=20,
    mode='min',            
    restore_best_weights=True
)

history = model_nn.fit(
    X, y,
    epochs=200,
    batch_size=64,
    validation_split=0.2,
    callbacks=[early_stop],
    verbose=1
)
# Out:
# Epoch 1/200
# 815/815 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.6812 - loss: 0.6716 - val_accuracy: 0.7171 - val_loss: 0.5695
# Epoch 2/200
# 815/815 ━━━━━━━━━━━━━━━━━━━━ 1s 742us/step - accuracy: 0.7060 - loss: 0.6061 - val_accuracy: 0.7201 - val_loss: 0.5622
# Epoch 3/200
# 815/815 ━━━━━━━━━━━━━━━━━━━━ 1s 694us/step - accuracy: 0.7147 - loss: 0.5936 - val_accuracy: 0.7222 - val_loss: 0.5571
# Epoch 4/200
# 815/815 ━━━━━━━━━━━━━━━━━━━━ 1s 637us/step - accuracy: 0.7176 - loss: 0.5880 - val_accuracy: 0.7216 - val_loss: 0.5565
# Epoch 5/200
# 815/815 ━━━━━━━━━━━━━━━━━━━━ 1s 668us/step - accuracy: 0.7203 - loss: 0.5821 - val_accuracy: 0.7231 - val_loss: 0.5527
# Epoch 6/200
# 815/815 ━━━━━━━━━━━━━━━━━━━━ 1s 652us/step - accuracy: 0.7209 - loss: 0.5791 - val_accuracy: 0.7238 - val_loss: 0.5516
# Epoch 7/200
# 815/815 ━━━━━━━━━━━━━━━━━━━━ 1s 686us/step - accuracy: 0.7220 - loss: 0.5761 - val_accuracy: 0.7246 - val_loss: 0.5496
# Epoch 8/200
# 815/815 ━━━━━━━━━━━━━━━━━━━━ 1s 673us/step - accuracy: 0.7232 - loss: 0.5735 - val_accuracy: 0.7246 - val_loss: 0.5482
# Epoch 9/200
# 815/815 ━━━━━━━━━━━━━━━━━━━━ 1s 654us/step - accuracy: 0.7233 - loss: 0.5713 - val_accuracy: 0.7246 - val_loss: 0.5476
# Epoch 10/200
# 815/815 ━━━━━━━━━━━━━━━━━━━━ 1s 643us/step - accuracy: 0.7243 - loss: 0.5704 - val_accuracy: 0.7243 - val_loss: 0.5470
# Epoch 11/200
# 815/815 ━━━━━━━━━━━━━━━━━━━━ 1s 624us/step - accuracy: 0.7245 - loss: 0.5697 - val_accuracy: 0.7244 - val_loss: 0.5487
# Epoch 12/200
# 815/815 ━━━━━━━━━━━━━━━━━━━━ 1s 636us/step - accuracy: 0.7253 - loss: 0.5681 - val_accuracy: 0.7245 - val_loss: 0.5464
# Epoch 13/200
# 815/815 ━━━━━━━━━━━━━━━━━━━━ 1s 635us/step - accuracy: 0.7251 - loss: 0.5664 - val_accuracy: 0.7248 - val_loss: 0.5468
# Epoch 14/200
# 815/815 ━━━━━━━━━━━━━━━━━━━━ 1s 632us/step - accuracy: 0.7251 - loss: 0.5664 - val_accuracy: 0.7250 - val_loss: 0.5469
# Epoch 15/200
# 815/815 ━━━━━━━━━━━━━━━━━━━━ 1s 637us/step - accuracy: 0.7250 - loss: 0.5649 - val_accuracy: 0.7248 - val_loss: 0.5459
# Epoch 16/200
# 815/815 ━━━━━━━━━━━━━━━━━━━━ 1s 634us/step - accuracy: 0.7257 - loss: 0.5643 - val_accuracy: 0.7247 - val_loss: 0.5460
# Epoch 17/200
# 815/815 ━━━━━━━━━━━━━━━━━━━━ 1s 634us/step - accuracy: 0.7259 - loss: 0.5642 - val_accuracy: 0.7250 - val_loss: 0.5450
# Epoch 18/200
# 815/815 ━━━━━━━━━━━━━━━━━━━━ 1s 644us/step - accuracy: 0.7260 - loss: 0.5621 - val_accuracy: 0.7248 - val_loss: 0.5452
# Epoch 19/200
# 815/815 ━━━━━━━━━━━━━━━━━━━━ 1s 626us/step - accuracy: 0.7260 - loss: 0.5632 - val_accuracy: 0.7247 - val_loss: 0.5453
# Epoch 20/200
# 815/815 ━━━━━━━━━━━━━━━━━━━━ 1s 626us/step - accuracy: 0.7258 - loss: 0.5627 - val_accuracy: 0.7249 - val_loss: 0.5459
# Epoch 21/200
# 815/815 ━━━━━━━━━━━━━━━━━━━━ 1s 630us/step - accuracy: 0.7261 - loss: 0.5615 - val_accuracy: 0.7250 - val_loss: 0.5449
# Epoch 22/200
# 815/815 ━━━━━━━━━━━━━━━━━━━━ 1s 623us/step - accuracy: 0.7266 - loss: 0.5609 - val_accuracy: 0.7248 - val_loss: 0.5462
# Epoch 23/200
# 815/815 ━━━━━━━━━━━━━━━━━━━━ 1s 632us/step - accuracy: 0.7264 - loss: 0.5606 - val_accuracy: 0.7246 - val_loss: 0.5460
# Epoch 24/200
# 815/815 ━━━━━━━━━━━━━━━━━━━━ 1s 635us/step - accuracy: 0.7260 - loss: 0.5605 - val_accuracy: 0.7249 - val_loss: 0.5456
# Epoch 25/200
# 815/815 ━━━━━━━━━━━━━━━━━━━━ 1s 630us/step - accuracy: 0.7267 - loss: 0.5599 - val_accuracy: 0.7246 - val_loss: 0.5457
# Epoch 26/200
# 815/815 ━━━━━━━━━━━━━━━━━━━━ 1s 639us/step - accuracy: 0.7271 - loss: 0.5587 - val_accuracy: 0.7248 - val_loss: 0.5443
# Epoch 27/200
# 815/815 ━━━━━━━━━━━━━━━━━━━━ 1s 642us/step - accuracy: 0.7267 - loss: 0.5587 - val_accuracy: 0.7246 - val_loss: 0.5456
# Epoch 28/200
# 815/815 ━━━━━━━━━━━━━━━━━━━━ 1s 635us/step - accuracy: 0.7268 - loss: 0.5598 - val_accuracy: 0.7246 - val_loss: 0.5463
# Epoch 29/200
# 815/815 ━━━━━━━━━━━━━━━━━━━━ 1s 639us/step - accuracy: 0.7266 - loss: 0.5588 - val_accuracy: 0.7246 - val_loss: 0.5454
# Epoch 30/200
# 815/815 ━━━━━━━━━━━━━━━━━━━━ 1s 851us/step - accuracy: 0.7268 - loss: 0.5599 - val_accuracy: 0.7246 - val_loss: 0.5463
# Epoch 31/200
# 815/815 ━━━━━━━━━━━━━━━━━━━━ 1s 690us/step - accuracy: 0.7266 - loss: 0.5593 - val_accuracy: 0.7241 - val_loss: 0.5460
# Epoch 32/200
# 815/815 ━━━━━━━━━━━━━━━━━━━━ 1s 964us/step - accuracy: 0.7267 - loss: 0.5592 - val_accuracy: 0.7247 - val_loss: 0.5453
# Epoch 33/200
# 815/815 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7269 - loss: 0.5580 - val_accuracy: 0.7248 - val_loss: 0.5456
# Epoch 34/200
# 815/815 ━━━━━━━━━━━━━━━━━━━━ 1s 853us/step - accuracy: 0.7268 - loss: 0.5588 - val_accuracy: 0.7249 - val_loss: 0.5451
# Epoch 35/200
# 815/815 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7271 - loss: 0.5581 - val_accuracy: 0.7250 - val_loss: 0.5453
# Epoch 36/200
# 815/815 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7270 - loss: 0.5570 - val_accuracy: 0.7247 - val_loss: 0.5455
# Epoch 37/200
# 815/815 ━━━━━━━━━━━━━━━━━━━━ 1s 840us/step - accuracy: 0.7269 - loss: 0.5592 - val_accuracy: 0.7249 - val_loss: 0.5456
# Epoch 38/200
# 815/815 ━━━━━━━━━━━━━━━━━━━━ 1s 813us/step - accuracy: 0.7270 - loss: 0.5573 - val_accuracy: 0.7248 - val_loss: 0.5450
# Epoch 39/200
# 815/815 ━━━━━━━━━━━━━━━━━━━━ 1s 776us/step - accuracy: 0.7271 - loss: 0.5578 - val_accuracy: 0.7243 - val_loss: 0.5464
# Epoch 40/200
# 815/815 ━━━━━━━━━━━━━━━━━━━━ 1s 861us/step - accuracy: 0.7269 - loss: 0.5572 - val_accuracy: 0.7250 - val_loss: 0.5461
# Epoch 41/200
# 815/815 ━━━━━━━━━━━━━━━━━━━━ 1s 805us/step - accuracy: 0.7269 - loss: 0.5575 - val_accuracy: 0.7249 - val_loss: 0.5449
# Epoch 42/200
# 815/815 ━━━━━━━━━━━━━━━━━━━━ 1s 769us/step - accuracy: 0.7270 - loss: 0.5580 - val_accuracy: 0.7249 - val_loss: 0.5456
# Epoch 43/200
# 815/815 ━━━━━━━━━━━━━━━━━━━━ 1s 699us/step - accuracy: 0.7271 - loss: 0.5577 - val_accuracy: 0.7251 - val_loss: 0.5448
# Epoch 44/200
# 815/815 ━━━━━━━━━━━━━━━━━━━━ 1s 719us/step - accuracy: 0.7273 - loss: 0.5568 - val_accuracy: 0.7246 - val_loss: 0.5465
# Epoch 45/200
# 815/815 ━━━━━━━━━━━━━━━━━━━━ 1s 673us/step - accuracy: 0.7269 - loss: 0.5570 - val_accuracy: 0.7249 - val_loss: 0.5458
# Epoch 46/200
# 815/815 ━━━━━━━━━━━━━━━━━━━━ 1s 674us/step - accuracy: 0.7272 - loss: 0.5565 - val_accuracy: 0.7249 - val_loss: 0.5458

# %%
plt.plot(history.history['loss'],     label='Train loss')
plt.plot(history.history['val_loss'], label='Val loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')

plt.title('Neural Network — Training History', fontweight='bold')
plt.legend()
plt.show()

# %%
Pred_y_nn= model_nn.predict(X_test_matrix)
# Out:
# 509/509 ━━━━━━━━━━━━━━━━━━━━ 0s 295us/step

# %%
pred_nn = np.argmax(Pred_y_nn, axis=1)

print(classification_report(y_test, pred_nn, target_names=le.classes_.astype(str)))
# Out:
#               precision    recall  f1-score   support
#
#   figurative       0.38      0.00      0.00      4248
#        irony       0.66      0.97      0.78      4179
#      regular       0.93      0.99      0.96      3719
#      sarcasm       0.66      0.99      0.79      4136
#
#     accuracy                           0.73     16282
#    macro avg       0.66      0.74      0.63     16282
# weighted avg       0.65      0.73      0.62     16282

# %%
cmnn = confusion_matrix(y_test, pred_nn)
ConfusionMatrixDisplay(cmnn, display_labels=le.classes_.astype(str)).plot(cmap='Blues')
plt.show()

# %% [markdown]
# LSTMs

# %%
from tensorflow.keras.layers import LSTM, Embedding, SpatialDropout1D

def build_lstm(vocab_size, embedding_dim=64, max_len=50):
    model = Sequential([
        # maps token integers to dense vectors
        Embedding(input_dim=vocab_size, output_dim=embedding_dim, input_length=max_len),
        SpatialDropout1D(0.2),
        
        # sequence modelling
        LSTM(128, return_sequences=True),
        Dropout(0.2),
        
        LSTM(64),
        Dropout(0.2),
        
        # classification head
        Dense(32, activation='relu'),
        Dense(4, activation='softmax')
    ])
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
        loss='sparse_categorical_crossentropy',
        metrics=['accuracy']
    )
    return model

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

tokenizer = Tokenizer(num_words=10000, oov_token='<OOV>')
tokenizer.fit_on_texts(X_train)

X_train_seq = pad_sequences(tokenizer.texts_to_sequences(X_train), maxlen=50)
X_test_seq  = pad_sequences(tokenizer.texts_to_sequences(X_test),  maxlen=50)

vocab_size = min(tokenizer.num_words, len(tokenizer.word_index) + 1)
model_lstm = build_lstm(vocab_size)
model_lstm.build(input_shape=(None, 50))  # None = batch size, 50 = max_len
print(model_lstm.summary())
# Out:
# /usr/local/lib/python3.13/site-packages/keras/src/layers/core/embedding.py:103: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_1 (Embedding)         │ (None, 50, 64)         │       640,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ spatial_dropout1d_1             │ (None, 50, 64)         │             0 │
# │ (SpatialDropout1D)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_2 (LSTM)                   │ (None, 50, 128)        │        98,816 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ (None, 50, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_3 (LSTM)                   │ (None, 64)             │        49,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_9 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 4)              │           132 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 790,436 (3.02 MB)
#  Trainable params: 790,436 (3.02 MB)
#  Non-trainable params: 0 (0.00 B)
# None

# %%
early_stop = EarlyStopping(
    monitor='val_loss',
    patience=20,
    mode='min',            
    restore_best_weights=True
)

history_lstm = model_lstm.fit(
    X_train_seq, y_train,
    epochs=200,
    batch_size=64,
    validation_split=0.2,
    callbacks=[early_stop],
    verbose=1
)
# Out:
# Epoch 1/200
# 815/815 ━━━━━━━━━━━━━━━━━━━━ 46s 53ms/step - accuracy: 0.7126 - loss: 0.5674 - val_accuracy: 0.7358 - val_loss: 0.5000
# Epoch 2/200
# 815/815 ━━━━━━━━━━━━━━━━━━━━ 48s 59ms/step - accuracy: 0.7392 - loss: 0.4999 - val_accuracy: 0.7359 - val_loss: 0.4986
# Epoch 3/200
# 815/815 ━━━━━━━━━━━━━━━━━━━━ 53s 64ms/step - accuracy: 0.7398 - loss: 0.4959 - val_accuracy: 0.7358 - val_loss: 0.4999
# Epoch 4/200
# 815/815 ━━━━━━━━━━━━━━━━━━━━ 50s 61ms/step - accuracy: 0.7499 - loss: 0.4810 - val_accuracy: 0.7293 - val_loss: 0.5102
# Epoch 5/200
# 815/815 ━━━━━━━━━━━━━━━━━━━━ 45s 55ms/step - accuracy: 0.7618 - loss: 0.4628 - val_accuracy: 0.7266 - val_loss: 0.5205
# Epoch 6/200
# 815/815 ━━━━━━━━━━━━━━━━━━━━ 40s 49ms/step - accuracy: 0.7717 - loss: 0.4438 - val_accuracy: 0.7152 - val_loss: 0.5555
# Epoch 7/200
# 815/815 ━━━━━━━━━━━━━━━━━━━━ 40s 49ms/step - accuracy: 0.7836 - loss: 0.4255 - val_accuracy: 0.6981 - val_loss: 0.6023
# Epoch 8/200
# 815/815 ━━━━━━━━━━━━━━━━━━━━ 40s 50ms/step - accuracy: 0.7938 - loss: 0.4058 - val_accuracy: 0.6902 - val_loss: 0.6441
# Epoch 9/200
# 815/815 ━━━━━━━━━━━━━━━━━━━━ 40s 50ms/step - accuracy: 0.8021 - loss: 0.3917 - val_accuracy: 0.6795 - val_loss: 0.6628
# Epoch 10/200
# 815/815 ━━━━━━━━━━━━━━━━━━━━ 53s 65ms/step - accuracy: 0.8131 - loss: 0.3716 - val_accuracy: 0.6682 - val_loss: 0.7202
# Epoch 11/200
# 815/815 ━━━━━━━━━━━━━━━━━━━━ 49s 60ms/step - accuracy: 0.8193 - loss: 0.3618 - val_accuracy: 0.6624 - val_loss: 0.7469
# Epoch 12/200
# 815/815 ━━━━━━━━━━━━━━━━━━━━ 47s 58ms/step - accuracy: 0.8283 - loss: 0.3446 - val_accuracy: 0.6629 - val_loss: 0.7864
# Epoch 13/200
# 815/815 ━━━━━━━━━━━━━━━━━━━━ 46s 57ms/step - accuracy: 0.8358 - loss: 0.3329 - val_accuracy: 0.6666 - val_loss: 0.7931
# Epoch 14/200
# 815/815 ━━━━━━━━━━━━━━━━━━━━ 55s 68ms/step - accuracy: 0.8400 - loss: 0.3251 - val_accuracy: 0.6623 - val_loss: 0.8112
# Epoch 15/200
# 815/815 ━━━━━━━━━━━━━━━━━━━━ 57s 70ms/step - accuracy: 0.8455 - loss: 0.3149 - val_accuracy: 0.6515 - val_loss: 0.8139
# Epoch 16/200
# 815/815 ━━━━━━━━━━━━━━━━━━━━ 52s 63ms/step - accuracy: 0.8505 - loss: 0.3051 - val_accuracy: 0.6449 - val_loss: 0.8603
# Epoch 17/200
# 815/815 ━━━━━━━━━━━━━━━━━━━━ 49s 60ms/step - accuracy: 0.8551 - loss: 0.2975 - val_accuracy: 0.6466 - val_loss: 0.9058
# Epoch 18/200
# 815/815 ━━━━━━━━━━━━━━━━━━━━ 56s 69ms/step - accuracy: 0.8605 - loss: 0.2881 - val_accuracy: 0.6459 - val_loss: 0.9056
# Epoch 19/200
# 815/815 ━━━━━━━━━━━━━━━━━━━━ 42s 51ms/step - accuracy: 0.8611 - loss: 0.2851 - val_accuracy: 0.6400 - val_loss: 0.9329
# Epoch 20/200
# 815/815 ━━━━━━━━━━━━━━━━━━━━ 40s 49ms/step - accuracy: 0.8668 - loss: 0.2761 - val_accuracy: 0.6339 - val_loss: 0.9825
# Epoch 21/200
# 815/815 ━━━━━━━━━━━━━━━━━━━━ 46s 56ms/step - accuracy: 0.8675 - loss: 0.2758 - val_accuracy: 0.6356 - val_loss: 0.9641
# Epoch 22/200
# 815/815 ━━━━━━━━━━━━━━━━━━━━ 48s 59ms/step - accuracy: 0.8693 - loss: 0.2715 - val_accuracy: 0.6314 - val_loss: 0.9960

# %%
Pred_y_lstm= model_lstm.predict(X_test_seq)
# Out:
# 509/509 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step

# %%
pred_lstm = np.argmax(Pred_y_lstm, axis=1)

print(classification_report(y_test, pred_lstm, target_names=le.classes_.astype(str)))
# Out:
#               precision    recall  f1-score   support
#
#   figurative       0.22      0.00      0.00      4248
#        irony       0.66      1.00      0.79      4179
#      regular       1.00      1.00      1.00      3719
#      sarcasm       0.66      1.00      0.80      4136
#
#     accuracy                           0.74     16282
#    macro avg       0.64      0.75      0.65     16282
# weighted avg       0.62      0.74      0.63     16282

# %%
cmlstm = confusion_matrix(y_test, pred_lstm)
ConfusionMatrixDisplay(cmlstm, display_labels=le.classes_.astype(str)).plot(cmap='Blues')
plt.show()

# %% [markdown]
# AUC-ROC Curves

# %%
from sklearn.metrics import roc_auc_score, roc_curve
from sklearn.preprocessing import label_binarize

y_bin = label_binarize(y_test, classes=[0,1,2,3])

models = {
    'Random Forest':           (model_rf,   X_test_matrix),
    'XGBoost':                 (model_x,    X_test_matrix),
    'Multinomial Naive Bayes': (MB,          X_test_matrix),
    'Neural Network':          (model_nn,    X_test_matrix),
    'LSTM':                    (model_lstm,  X_test_seq)
}

plt.figure(figsize=(9, 6))

for name, (model, X_feat) in models.items():
    proba = model.predict(X_feat) if isinstance(model, tf.keras.Model) \
            else model.predict_proba(X_feat)
    auc = roc_auc_score(y_test, proba, multi_class='ovr')
    mean_fpr = np.linspace(0, 1, 100)
    mean_tpr = np.zeros(100)
    for i in range(4):
        fpr, tpr, _ = roc_curve(y_bin[:, i], proba[:, i])
        mean_tpr += np.interp(mean_fpr, fpr, tpr)
    mean_tpr /= 4
    plt.plot(mean_fpr, mean_tpr, label=f'{name} (AUC = {auc:.4f})')

plt.plot([0,1],[0,1],'k--', label='Random')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curves — All Models (OVR Macro Average)')
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# 509/509 ━━━━━━━━━━━━━━━━━━━━ 0s 249us/step
# 509/509 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step

# %%
predictions = {
    'Naive Bayes':    Pred_y_nb,
    'Random Forest':  Pred_y_rf,
    'XGBoost':        Pred_y_x,
    'Neural Network': pred_nn,
    'LSTM':           pred_lstm
}

fig, axes = plt.subplots(2, 3, figsize=(18, 10))
axes = axes.flatten()

for ax, (name, preds) in zip(axes, predictions.items()):
    cm = confusion_matrix(y_test, preds)
    ConfusionMatrixDisplay(cm, display_labels=le.classes_.astype(str)).plot(
        cmap='Blues', ax=ax, colorbar=False
    )
    ax.set_title(name, fontweight='bold')

axes[-1].axis('off')  # hide the empty 6th subplot
plt.suptitle('Confusion Matrices — All Models', fontweight='bold', y=1.02)
plt.tight_layout()
plt.show()
